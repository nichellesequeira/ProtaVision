# %%
from protavision.functions import proportion_amino_acid
sequence1 = "ACDEFGHIKLMNPQRSTVWY"
sequence2 = "AAAAAAAAAAAAAAAAAAAA"
proportion_amino_acid(sequence1, sequence2);
